# %%
class BankAccount:

    def __init__(self,owner,balance):
        self.owner = owner
        self.balance = balance

    def deposit(self,amount):
         self.balance = self.balance + amount
         print(f"added {amount} to your account")

    def withdraw(self,withdraw):
        if self.balance >= withdraw:
            self.balance = self.balance - withdraw
            print("withdrawl accepted ")
        else:
            print("un sufficient funds")

    def __str__(self):
        return f"owner : {self.owner} \nbalance : {self.balance}"

# %%
t1=BankAccount('siva',100)

# %%
t1

# %%
print(t1)
# Out:
# owner : siva
# balance : 100

# %%
t1.deposit
# Out:
# <bound method BankAccount.deposit of <__main__.BankAccount object at 0x0000026D3EF48680>>

# %%
t1.owner
# Out:
# 'siva'

# %%
t1.deposit(200)
# Out:
# added 200 to your account

# %%
t1.balance
# Out:
# 300

# %%
t1.withdraw(150)
# Out:
# withdrawl accepted

# %%
t1.balance
# Out:
# 150
